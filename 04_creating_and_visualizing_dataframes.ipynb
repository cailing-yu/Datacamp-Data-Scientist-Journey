# %% [markdown]
# Date: 6/11/2026
#
# Theme: Creating & Visualizing DataFrames
#
# Business Problems:
#     1. Visualizing your data: 瞬间捕捉到数据的异常分布或潜在趋势。
#     2. Missing values: 由于系统宕机、用户漏填，数据永远是破碎的。

# %%
import matplotlib.pyplot as plt
